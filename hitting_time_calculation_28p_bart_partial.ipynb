# %%
### inputs ###
task = "bart" # rest or bart
atLas = "mmp" # msdl or haox or mmp

# %%
import os
# %matplotlib inline
import nilearn
import numpy as np
import scipy
import math
from nilearn import datasets
from nilearn.input_data import NiftiMapsMasker
from nilearn.input_data import NiftiLabelsMasker
from nilearn.connectome import ConnectivityMeasure
import nibabel as nib
import openpyxl
import matplotlib.pyplot as plt
import csv
import pandas as pd
# from sklearn.covariance import GraphLassoCV
correlation_measure = ConnectivityMeasure(kind='partial correlation')

# %%
# estimator = GraphLassoCV()
atlas_filename = "MMP1_rois.nii"
masker = NiftiLabelsMasker(labels_img=atlas_filename, standardize=True,
                           memory='nilearn_cache', verbose=5)

# %%
## reading the subject's ID's and groups
wb = openpyxl.load_workbook('Subjects1.xlsx')
wb.get_sheet_names()
sheet = wb.get_sheet_by_name('Sheet1')
N = sheet.max_row
# Out:
# c:\users\paria\appdata\local\programs\python\python36\lib\site-packages\openpyxl\reader\worksheet.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# Data_DIR = "/Volumes/Seagate/UCLA/func/"
Data_DIR = "F://UCLA//func/"
os.chdir(Data_DIR)
os.getcwd()
# Out:
# 'F:\\UCLA\\func'

# %%
## this function calculates hitting-time matrix
def hitting_matrix(correlation_matrix):
    L = np.size(correlation_matrix,axis = 0)
    A_matrix = abs(correlation_matrix)
    np.fill_diagonal(A_matrix, 0)
    
    D_matrix = np.zeros((L,L))
    D_inv = np.zeros((L,L))
    D_sqrt = np.zeros((L,L))
    D_sqrt_inv = np.zeros((L,L))
    for i in range(L):
        D_matrix[i,i] = np.sum(A_matrix[i])
        D_inv[i,i] = 1./D_matrix[i,i]
        D_sqrt[i,i] = np.sqrt(D_matrix[i,i])
        D_sqrt_inv[i,i] = 1./D_sqrt[i,i]

    p_matrix = np.dot(D_inv, A_matrix)
    # Graph Laplacian
    eye_matrix = np.eye(L,L)
    eye_P = eye_matrix - p_matrix

    G_Lap = np.dot(D_sqrt,eye_P)
    G_Lap_n = np.dot(G_Lap, D_sqrt_inv)

    # T = p_matrix
    [eig_val, eig_vec] = np.linalg.eigh(G_Lap_n)
    # print eig_val
    H = np.zeros((L,L))
    d = np.sum(D_matrix)
    for i in range(L):
        for j in range(L):
            deg_i = D_matrix[i,i]
            deg_j = D_matrix[j,j]
            for k in range(L):
                if eig_val[k] != min(eig_val):
                    t_i = (eig_vec[i,k]*eig_vec[i,k])/deg_i
                    t_j = (eig_vec[j,k]*eig_vec[j,k])/deg_j
                    t_ij = (eig_vec[i,k]*eig_vec[j,k])/np.sqrt(deg_i*deg_j)
                    H[i,j] = H[i,j] + d*(1./(eig_val[k]))*(t_j-t_ij)

    H = np.transpose(H)
    return H

# %%
## calculating and saving hitting-time matrix for every subject
for i in range(1,N):
    ID = sheet.cell(row=i+1, column=1).value
    sub = str(ID) 
    Data_Name = "sub-" + sub + "_task-" + task + "_bold_space-MNI152NLin2009cAsym_preproc"    
    # set the name of the desired data set here:
    fmri_filenames = Data_Name + "_filt.nii.gz"
#     data_confs = nilearn.image.high_variance_confounds(fmri_filenames, n_confounds=5, 
#                                                        percentile=2.0, detrend=True, mask_img=None)
    tsv_file = "sub-" + sub+ "_task-" + task + "_bold_confounds.tsv"
    df = pd.read_table(tsv_file, sep='\t', header=0)
    [dim1, dim2] = np.shape(df)
    conf_clmns = [row for row in df if row == "WhiteMatter" or row == "X" or row == "Y" or row == "Z" or row == "RotX" or row == "RotY" or row == "RotZ"]
    data_confs = np.zeros((dim1, 4*7))
    cntr = 0
    for item in conf_clmns:
        data_confs[:, cntr] = np.array(df[item])
        data_confs[:, cntr+7] = np.gradient(data_confs[:, cntr])
        data_confs[:, cntr+2*7] = np.gradient(data_confs[:, cntr+8])
        data_confs[:, cntr+3*7] = np.square(data_confs[:, cntr+2*8])
        cntr = cntr + 1
    data_confs = data_confs[5:,:]
    
    time_series = masker.fit_transform(fmri_filenames, confounds = data_confs)
#     estimator.fit(time_series)
#     precision_matrix = estimator.precision_ 

    correlation_matrix = correlation_measure.fit_transform([time_series])[0]  
    np.savetxt("correlation_partial_" + atLas + "_data_28p_" + Data_Name, correlation_matrix, delimiter=",")
    
    L = np.size(correlation_matrix,axis = 0)
    A_matrix = abs(correlation_matrix)
    np.fill_diagonal(A_matrix, 0)
    
    D_matrix = np.zeros((L,L))
    D_inv = np.zeros((L,L))

    for i in range(L):
        D_matrix[i,i] = np.sum(A_matrix[i])
        D_inv[i,i] = 1./D_matrix[i,i]

    p_matrix = np.dot(D_inv, A_matrix)
    np.savetxt("p_partial_" + atLas + "_data_28p_" + Data_Name, p_matrix, delimiter=",")

    H = hitting_matrix(correlation_matrix)
    np.savetxt("hit_time_" + atLas + "_data_28p_filt_partial_" + Data_Name, H, delimiter=",")
# Out:
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# Resampling labels
# [Memory]    0.0s, 0.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]    8.3s, 0.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]   15.8s, 0.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]   18.4s, 0.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('sub-10217_task-bart_bold_space-MNI152NLin2009cAsym_preproc_filt.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x0000020EBE4758D0>,
# { 'background_label': 0,
#   'detrend': False,
#   'high_pass': None,
#   'labels_img': 'MMP1_rois.nii',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': None,
#   'standardize': True,
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=array([[-2.457631, ...,  0.      ],
#        ...,
#        [-0.830106, ...,  0.      ]]), memory=Memory(cachedir='nilearn_cache\\joblib'), memory_level=1, verbose=5)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from sub-10217_task-bart_bold_space-MNI152NLin2009cAsym_preproc_filt.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# _______________________________________________filter_and_extract - 6.0s, 0.1min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]   39.6s, 0.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]   48.9s, 0.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]   69.6s, 1.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]   86.2s, 1.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  104.0s, 1.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  118.2s, 2.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  131.9s, 2.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  142.0s, 2.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  162.7s, 2.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  176.8s, 2.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  185.0s, 3.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  200.8s, 3.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  216.7s, 3.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  231.2s, 3.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  246.6s, 4.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  263.9s, 4.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  285.0s, 4.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  303.0s, 5.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  321.0s, 5.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  339.3s, 5.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  356.5s, 5.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  377.1s, 6.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  388.7s, 6.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  400.1s, 6.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  408.6s, 6.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  424.2s, 7.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  446.9s, 7.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  467.3s, 7.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  477.1s, 8.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  495.2s, 8.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  512.7s, 8.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  525.1s, 8.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  542.6s, 9.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  550.6s, 9.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  562.4s, 9.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]  582.4s, 9.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 613.2s, 10.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 658.9s, 11.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 707.4s, 11.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 741.9s, 12.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 778.8s, 13.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 816.9s, 13.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 859.8s, 14.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 903.7s, 15.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 949.9s, 15.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory] 981.9s, 16.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1021.8s, 17.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1057.7s, 17.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1094.3s, 18.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1126.3s, 18.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.4s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1166.6s, 19.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1204.0s, 20.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1242.1s, 20.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1280.9s, 21.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1319.7s, 22.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1361.2s, 22.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1406.0s, 23.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1442.0s, 24.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1481.6s, 24.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1517.6s, 25.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1552.0s, 25.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1579.7s, 26.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1615.5s, 26.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1651.9s, 27.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1685.9s, 28.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.4s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1719.5s, 28.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1766.2s, 29.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1812.2s, 30.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1853.8s, 30.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1890.7s, 31.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1929.9s, 32.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]1966.5s, 32.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2001.0s, 33.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2039.4s, 34.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2076.6s, 34.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2105.2s, 35.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2145.4s, 35.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2184.6s, 36.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2229.5s, 37.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2275.3s, 37.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2325.4s, 38.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2392.9s, 39.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2449.4s, 40.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.4s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2525.6s, 42.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2580.5s, 43.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2636.4s, 43.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2691.2s, 44.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2747.3s, 45.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2796.3s, 46.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2845.6s, 47.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2893.5s, 48.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]2959.2s, 49.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3014.9s, 50.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3073.3s, 51.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3124.8s, 52.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3181.1s, 53.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3241.1s, 54.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3307.6s, 55.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3359.3s, 56.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3421.3s, 57.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3482.1s, 58.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3543.2s, 59.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3592.3s, 59.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3643.7s, 60.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3688.7s, 61.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3748.2s, 62.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3803.6s, 63.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3861.5s, 64.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3915.1s, 65.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]3974.1s, 66.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4029.0s, 67.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.4s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4090.0s, 68.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4150.8s, 69.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4198.6s, 70.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4244.9s, 70.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4308.1s, 71.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4377.0s, 73.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4439.7s, 74.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4503.2s, 75.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4546.9s, 75.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4598.3s, 76.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4657.5s, 77.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4709.0s, 78.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4768.3s, 79.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4832.9s, 80.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4884.0s, 81.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4940.2s, 82.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]4991.8s, 83.2min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5041.7s, 84.0min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5093.0s, 84.9min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5150.4s, 85.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5205.8s, 86.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5269.5s, 87.8min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5319.6s, 88.7min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5369.1s, 89.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5433.2s, 90.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5493.1s, 91.6min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5551.8s, 92.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.2s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5607.1s, 93.5min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5663.1s, 94.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5724.4s, 95.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.3s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5783.0s, 96.4min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5839.4s, 97.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5896.5s, 98.3min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.4s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]5946.5s, 99.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]6005.4s, 100.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.0s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
# [Memory]6064.9s, 101.1min: Loading filter_and_extract...
# __________________________________filter_and_extract cache loaded - 0.1s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from MMP1_rois.nii
